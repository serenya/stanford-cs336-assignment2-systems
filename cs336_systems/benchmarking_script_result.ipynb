# %% [markdown]
# # Benchmarking results
#
# ## Forward and backward passes with 5 warmup steps
#
# | Model   |   Forward Time Avg |   Forward Time Std |   Backward Time Avg |   Backward Time Std |
# |:--------|-------------------:|-------------------:|--------------------:|--------------------:|
# | small   |          0.0304429 |        0.000941216 |           0.0550669 |         0.0672984   |
# | medium  |          0.0595538 |        0.000448079 |           0.0764467 |         0.000505881 |
# | large   |          0.104408  |        0.00923747  |           0.1758    |         0.0007457   |
# | xl      |          0.206449  |        0.0204041   |           0.408432  |         0.191805    |
# | 2.7B    |          0.290992  |        0.03933     |           0.53846   |         0.132705    |

# %% [markdown]
# ## Forward and backward passes without warmup steps
#
# | Model   |   Forward Time Avg |   Forward Time Std |   Backward Time Avg |   Backward Time Std |
# |:--------|-------------------:|-------------------:|--------------------:|--------------------:|
# | small   |          0.0605927 |          0.10539   |           0.041686  |         0.0392413   |
# | medium  |          0.0497758 |          0.0128579 |           0.0579095 |         0.00623851  |
# | large   |          0.0828836 |          0.0402843 |           0.0885141 |         0.0105575   |
# | xl      |          0.0941851 |          0.0132358 |           0.151999  |         0.000443459 |
# | 2.7B    |          0.0915848 |          0.015695  |           0.22192   |         0.00218822  |

# %% [markdown]
# ## Conclusions
#
# - Forward pass takes between 0.029 - 0.1 seconds.
# - From the results above we can notice that forward pass takes in average 1.2-2 times more than forward pass.
# - Standard deviation for the forward pass is very small ~ 1%, and for backward pass ~ 10%
# - In case absence of warmup steps average time increase for both forward and backwards passes around 1.2-1.5 times. The reason for that is probably the model hasn't been loaded into the memory.
